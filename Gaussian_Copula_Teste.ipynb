# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-

"""
================================================================================
GAUSSIAN COPULA + BOOTSTRAP PARA DATASET TIPS (Restaurant Tips)
Versão com 2 contínuas e 5 ordinais (size, day, time, smoker, sex)
================================================================================
"""

# ============================================================================
# BLOCO 1: IMPORTAÇÕES E CONFIGURAÇÕES INICIAIS
# ============================================================================

import subprocess
import sys
import warnings
import time
import random
from IPython.display import display, HTML

CSS_STYLES = """
<style>
    .header {
        background: linear-gradient(135deg, #667eea 0%, #764ba2 100%);
        color: white;
        padding: 15px;
        border-radius: 10px;
        margin: 10px 0;
        text-align: center;
        font-family: Arial, sans-serif;
        font-weight: bold;
        font-size: 18px;
    }
    .success-box {
        background-color: #d4edda;
        color: #155724;
        padding: 12px;
        border: 1px solid #c3e6cb;
        border-radius: 5px;
        margin: 10px 0;
        font-weight: bold;
    }
    .warning-box {
        background-color: #fff3cd;
        color: #856404;
        padding: 12px;
        border: 1px solid #ffeaa7;
        border-radius: 5px;
        margin: 10px 0;
        font-weight: bold;
    }
    .info-box {
        background-color: #d1ecf1;
        color: #0c5460;
        padding: 12px;
        border: 1px solid #bee5eb;
        border-radius: 5px;
        margin: 10px 0;
    }
    .metrics-highlight {
        background: linear-gradient(135deg, #ffd89b 0%, #19547b 100%);
        color: white;
        padding: 15px;
        border-radius: 10px;
        margin: 10px 0;
        text-align: center;
        font-weight: bold;
    }
    .dataframe-table {
        font-family: Arial, sans-serif;
        border-collapse: collapse;
        width: 100%;
        box-shadow: 0 4px 8px rgba(0,0,0,0.1);
        border-radius: 10px;
        overflow: hidden;
        margin: 20px 0;
    }
    .dataframe-table th {
        background: linear-gradient(135deg, #2c3e50 0%, #3498db 100%);
        color: white;
        padding: 12px;
        text-align: left;
        font-weight: bold;
    }
    .dataframe-table td {
        padding: 10px;
        border-bottom: 1px solid #ddd;
    }
    .dataframe-table tr:nth-child(even) {
        background-color: #f8f9fa;
    }
    .dataframe-table tr:hover {
        background-color: #e9ecef;
        transform: scale(1.01);
        transition: all 0.2s ease;
    }
    .rubin-rules-box {
        background: linear-gradient(135deg, #667eea 0%, #764ba2 100%);
        color: white;
        padding: 15px;
        border-radius: 10px;
        margin: 10px 0;
        text-align: center;
        font-weight: bold;
    }
    .iteration-box {
        background-color: #e8f4fd;
        border-left: 5px solid #3498db;
        padding: 10px;
        margin: 10px 0;
        border-radius: 5px;
    }
    .encoding-badge {
        background: linear-gradient(135deg, #f093fb 0%, #f5576c 100%);
        color: white;
        padding: 5px 10px;
        border-radius: 15px;
        font-size: 12px;
        font-weight: bold;
        display: inline-block;
        margin: 2px;
    }
</style>
"""
display(HTML(CSS_STYLES))

def install(package):
    subprocess.check_call([sys.executable, "-m", "pip", "install", package])

for lib in ['numpy', 'pandas', 'scipy', 'scikit-learn', 'matplotlib', 'seaborn']:
    try:
        __import__(lib)
    except ImportError:
        install(lib)

import numpy as np
import pandas as pd
from scipy import stats
from sklearn.metrics import (accuracy_score, precision_score, recall_score,
                             f1_score, cohen_kappa_score, matthews_corrcoef)
import matplotlib.pyplot as plt
import seaborn as sns

try:
    from gcimpute.gaussian_copula import GaussianCopula
except ImportError:
    print("Instalando gcimpute do GitHub...")
    subprocess.check_call([sys.executable, "-m", "pip", "install",
                           "git+https://github.com/udellgroup/gcimpute.git"])
    from gcimpute.gaussian_copula import GaussianCopula

warnings.filterwarnings("ignore")
if not hasattr(np, 'round_'):
    np.round_ = np.round

# ============================================================================
# BLOCO 2: CONFIGURAÇÕES GLOBAIS
# ============================================================================

RANDOM_SEED = 42
BOOTSTRAP_ITERACOES = 100
M_IMPUTATIONS = 20
ALPHA = 0.05
MAX_ITER_EM = 200
TOL_EM = 0.001
np.random.seed(RANDOM_SEED)

# ============================================================================
# BLOCO 3: CARREGAMENTO E PRÉ-PROCESSAMENTO (TIPS) - 2 CONTÍNUAS, 5 ORDINAIS
# ============================================================================

display(HTML('<div class="header">🍽️ CARREGANDO DATASET TIPS (2 contínuas, 5 ordinais)</div>'))

tips = sns.load_dataset("tips")
df_raw = tips.copy()
display(HTML(f'<div class="success-box">✅ Dados carregados: {df_raw.shape[0]} linhas, {df_raw.shape[1]} colunas.</div>'))
display(HTML('<div class="info-box"><b>Primeiras linhas:</b></div>'))
display(df_raw.head().style.set_table_attributes('class="dataframe-table"'))

df_clean = df_raw.copy()

# Definição dos tipos
col_continuas = ["total_bill", "tip"]
col_ordinais = ["size", "day", "time", "smoker", "sex"]
col_nominais = []

# Define ordem para as categóricas (exceto size, que já é int)
df_clean['day'] = pd.Categorical(df_clean['day'], categories=['Thur','Fri','Sat','Sun'], ordered=True)
df_clean['time'] = pd.Categorical(df_clean['time'], categories=['Lunch','Dinner'], ordered=True)
df_clean['smoker'] = pd.Categorical(df_clean['smoker'], categories=['No','Yes'], ordered=True)
df_clean['sex'] = pd.Categorical(df_clean['sex'], categories=['Female','Male'], ordered=True)
# size permanece int

niveis_originais = {}
for col in col_ordinais + col_nominais:
    df_clean[col] = df_clean[col].astype("category")
    niveis_originais[col] = list(df_clean[col].cat.categories)

display(HTML('<div class="info-box"><b>Níveis das variáveis ordinais (com ordem):</b></div>'))
for col, lvls in niveis_originais.items():
    display(HTML(f'<span class="encoding-badge">{col}: {lvls}</span> '))

# Codificação para inteiros (preserva ordem)
df_cod = df_clean.copy()
for col in col_ordinais + col_nominais:
    df_cod[col] = df_cod[col].cat.codes

display(HTML('<div class="info-box"><b>Dados codificados (head):</b></div>'))
display(df_cod.head().style.set_table_attributes('class="dataframe-table"'))

colunas_ordenadas = list(df_cod.columns)
indices_continuas = [colunas_ordenadas.index(col) for col in col_continuas]
indices_ordinais = [colunas_ordenadas.index(col) for col in (col_ordinais + col_nominais)]

print("Índices contínuas:", indices_continuas)
print("Índices ordinais :", indices_ordinais)

# ============================================================================
# BLOCO 4: FUNÇÕES AUXILIARES (MISSING, IMPUTAÇÃO, MÉTRICAS)
# ============================================================================

def criar_missing_mcar_estratificado(df, percentual=0.75, random_seed=42):
    np.random.seed(random_seed)
    random.seed(random_seed)
    df_com_na = df.copy()
    posicoes_originais = {}
    for col in df.columns:
        n_missing = int(len(df) * percentual)
        indices = np.random.choice(df.index, size=n_missing, replace=False)
        for i in indices:
            posicoes_originais[(i, col)] = df.loc[i, col]
            df_com_na.loc[i, col] = np.nan
    return df_com_na, posicoes_originais

def imputacoes_gcimpute(df_na, indices_continuas, indices_ordinais,
                        m=M_IMPUTATIONS, random_seed=None, verbose=True,
                        maxit=MAX_ITER_EM, tol=TOL_EM,
                        use_conditional_mean=False):
    X = df_na.astype(float).values
    model = GaussianCopula(
        max_iter=maxit, tol=tol,
        random_state=random_seed if random_seed is not None else RANDOM_SEED,
        verbose=1 if verbose else 0,
    )
    if verbose:
        print(f"  Ajustando Gaussian Copula (EM)...")
        print(f"    contínuas: {indices_continuas}")
        print(f"    ordinais : {indices_ordinais}")
    model.fit(X, continuous=indices_continuas, ordinal=indices_ordinais)
    if use_conditional_mean:
        X_imp = model.transform(X)
        df_imp = pd.DataFrame(X_imp, columns=df_na.columns, index=df_na.index)
        datasets = [df_imp]
    else:
        X_imp = model.sample_imputation(X=X, num=m)
        datasets = [pd.DataFrame(X_imp[:, :, i], columns=df_na.columns, index=df_na.index) for i in range(m)]
    return datasets

def metricas_continuas(reais, imputados):
    mask = ~np.isnan(reais) & ~np.isnan(imputados)
    if mask.sum() < 2:
        return dict(rmse=np.nan, mae=np.nan, mse=np.nan, cor=np.nan, nrmse=np.nan,
                    nmae=np.nan, mape=np.nan, smape=np.nan, r2=np.nan)
    r = reais[mask]
    p = imputados[mask]
    mse = np.mean((r - p) ** 2)
    rmse = np.sqrt(mse)
    mae = np.mean(np.abs(r - p))
    cor = np.corrcoef(r, p)[0, 1] if len(r) > 1 else np.nan
    intervalo = np.ptp(r)
    nrmse = rmse / intervalo if intervalo > 0 else np.nan
    nmae = mae / intervalo if intervalo > 0 else np.nan
    with np.errstate(divide='ignore', invalid='ignore'):
        mape = np.mean(np.abs((r - p) / (r + 1e-8))) * 100
        mape = mape if np.isfinite(mape) else np.nan
    with np.errstate(divide='ignore', invalid='ignore'):
        denom = (np.abs(r) + np.abs(p) + 1e-8)
        smape = np.mean(2 * np.abs(r - p) / denom) * 100
        smape = smape if np.isfinite(smape) else np.nan
    ss_res = np.sum((r - p) ** 2)
    ss_tot = np.sum((r - np.mean(r)) ** 2)
    r2 = 1 - (ss_res / ss_tot) if ss_tot > 0 else np.nan
    return dict(rmse=rmse, mae=mae, mse=mse, cor=cor, nrmse=nrmse,
                nmae=nmae, mape=mape, smape=smape, r2=r2)

def erro_matriz_correlacao(df_original, df_imputado, col_continuas):
    orig = df_original[col_continuas].dropna()
    imp = df_imputado.loc[orig.index, col_continuas]
    cor_orig = orig.corr().values
    cor_imp = imp.corr().values
    diff = np.linalg.norm(cor_imp - cor_orig, 'fro')
    norm_orig = np.linalg.norm(cor_orig, 'fro')
    return diff / norm_orig if norm_orig > 0 else np.nan

def calcular_smae_por_coluna(valores_reais, valores_imputados, referencia):
    if len(valores_reais) == 0:
        return np.nan
    reais = np.array(valores_reais)
    imputados = np.array(valores_imputados)
    erro_imp = np.sum(np.abs(imputados - reais))
    erro_ref = np.sum(np.abs(referencia - reais))
    if erro_ref == 0:
        return np.nan
    return erro_imp / erro_ref

def gower_distance_matrix(df_real, df_imputado, col_continuas, col_categoricas):
    n = len(df_real)
    if n == 0:
        return np.nan
    all_cols = col_continuas + col_categoricas
    df_real_sub = df_real[all_cols].reset_index(drop=True)
    df_imp_sub = df_imputado[all_cols].reset_index(drop=True)
    gower_distances = np.zeros(n)
    for col in col_continuas:
        real_vals = df_real_sub[col].values
        imp_vals = df_imp_sub[col].values
        rng = np.ptp(real_vals)
        if rng == 0:
            rng = 1.0
        diff = np.abs(real_vals - imp_vals) / rng
        gower_distances += diff
    for col in col_categoricas:
        real_vals = df_real_sub[col].values
        imp_vals = df_imp_sub[col].values
        diff = (real_vals != imp_vals).astype(float)
        gower_distances += diff
    n_cols = len(all_cols)
    gower_distances /= n_cols
    return np.mean(gower_distances)

# ============================================================================
# BLOCO 5: REGRAS DE RUBIN
# ============================================================================

def rubin_pool(estimativas, m, alpha=0.05):
    estimativas = np.array(estimativas, dtype=float)
    estimativas = estimativas[~np.isnan(estimativas)]
    k = len(estimativas)
    if k == 0:
        return {'Q_bar': np.nan, 'se': np.nan, 'ci_lower': np.nan, 'ci_upper': np.nan}
    Q_bar = np.mean(estimativas)
    if k == 1:
        return {'Q_bar': Q_bar, 'se': 0.0, 'ci_lower': Q_bar, 'ci_upper': Q_bar}
    B = np.var(estimativas, ddof=1)
    T = (1 + 1/m) * B
    se = np.sqrt(T)
    gl = m - 1
    t_val = stats.t.ppf(1 - alpha/2, gl)
    ci_lower = Q_bar - t_val * se
    ci_upper = Q_bar + t_val * se
    return {'Q_bar': Q_bar, 'se': se, 'ci_lower': ci_lower, 'ci_upper': ci_upper}

# ============================================================================
# BLOCO 6: FUNÇÃO PRINCIPAL DE IMPUTAÇÃO + AVALIAÇÃO
# ============================================================================

def multiple_imputation_rubin_misto(df_na, posicoes_originais, df_original_clean,
                                    col_continuas, col_ordinais, col_nominais,
                                    indices_continuas, indices_ordinais,
                                    m=M_IMPUTATIONS, random_seed=RANDOM_SEED, show_progress=True,
                                    use_conditional_mean=False):
    # SMAE sobre contínuas e ordinais (todas as ordinais)
    col_continuas_smae = col_continuas                     # total_bill, tip
    col_ordinais_smae = col_ordinais                       # size, day, time, smoker, sex

    if show_progress:
        if use_conditional_mean:
            display(HTML(f'<div class="iteration-box">🔹 Gerando imputação por média condicional...</div>'))
        else:
            display(HTML(f'<div class="iteration-box">🔹 Gerando {m} imputações via gcimpute...</div>'))
    datasets = imputacoes_gcimpute(df_na, indices_continuas, indices_ordinais,
                                   m=m, random_seed=random_seed, verbose=show_progress,
                                   use_conditional_mean=use_conditional_mean)
    n_imp = len(datasets)
    if n_imp == 0:
        return dict(datasets=[], metricas_cat={}, metricas_cont={})

    medianas_cont = {col: df_original_clean[col].median() for col in col_continuas_smae}
    modas_cat = {}
    for col in col_ordinais_smae:
        moda = df_original_clean[col].mode()
        modas_cat[col] = moda.iloc[0] if len(moda) > 0 else np.nan

    acc_list, prec_list, rec_list, f1_list, kappa_list, mcc_list = [], [], [], [], [], []
    erro_cor_list = []
    dict_cont = {col: {met: [] for met in ['rmse','mae','mse','cor','nrmse','nmae','mape','smape','r2']} for col in col_continuas}
    smae_cont_por_coluna = {col: [] for col in col_continuas_smae}
    smae_cat_por_coluna = {col: [] for col in col_ordinais_smae}
    cols_categoricas = col_ordinais + col_nominais   # todas as categóricas (aqui são apenas ordinais)
    gower_list = []

    for i, df_imp in enumerate(datasets):
        if show_progress:
            display(HTML(f'<div class="metrics-highlight">📊 Avaliando imputação {i+1}/{n_imp}</div>'))
        err_cor = erro_matriz_correlacao(df_original_clean, df_imp, col_continuas)
        erro_cor_list.append(err_cor)

        # Avaliação categórica (todas as ordinais)
        reais_cat, preditos_cat = [], []
        reais_cat_por_col = {col: [] for col in cols_categoricas}
        imps_cat_por_col = {col: [] for col in cols_categoricas}
        for (linha, coluna), valor_real in posicoes_originais.items():
            if coluna in cols_categoricas:
                valor_imp = df_imp.at[linha, coluna]
                if pd.notna(valor_real) and pd.notna(valor_imp):
                    pred = int(round(valor_imp))
                    real = int(valor_real)
                    k = len(niveis_originais.get(coluna, [0]))
                    pred = max(0, min(pred, k-1))
                    reais_cat.append(real)
                    preditos_cat.append(pred)
                    reais_cat_por_col[coluna].append(real)
                    imps_cat_por_col[coluna].append(pred)
        if reais_cat:
            try:
                acc_list.append(accuracy_score(reais_cat, preditos_cat))
                prec_list.append(precision_score(reais_cat, preditos_cat, average='macro', zero_division=0))
                rec_list.append(recall_score(reais_cat, preditos_cat, average='macro', zero_division=0))
                f1_list.append(f1_score(reais_cat, preditos_cat, average='macro', zero_division=0))
                kappa_list.append(cohen_kappa_score(reais_cat, preditos_cat))
                mcc_list.append(matthews_corrcoef(reais_cat, preditos_cat))
            except:
                pass
            # SMAE ordinal (para cada coluna ordinal)
            for col in col_ordinais_smae:
                if col in reais_cat_por_col and reais_cat_por_col[col]:
                    smae = calcular_smae_por_coluna(reais_cat_por_col[col], imps_cat_por_col[col], modas_cat[col])
                    smae_cat_por_coluna[col].append(smae)

        # Avaliação contínua
        for col in col_continuas:
            reais_cont, imps_cont = [], []
            for (linha, coluna), valor_real in posicoes_originais.items():
                if coluna == col:
                    imp_val = df_imp.at[linha, col]
                    if pd.notna(valor_real) and pd.notna(imp_val):
                        reais_cont.append(valor_real)
                        imps_cont.append(imp_val)
            if reais_cont:
                met = metricas_continuas(np.array(reais_cont), np.array(imps_cont))
                for mname in dict_cont[col]:
                    dict_cont[col][mname].append(met[mname])
                if col in col_continuas_smae:
                    smae = calcular_smae_por_coluna(reais_cont, imps_cont, medianas_cont[col])
                    smae_cont_por_coluna[col].append(smae)

        # Distância de Gower
        real_dict = {}
        imp_dict = {}
        for (linha, coluna), val_real in posicoes_originais.items():
            if linha not in real_dict:
                real_dict[linha] = {}
                imp_dict[linha] = {}
            real_dict[linha][coluna] = val_real
            imp_dict[linha][coluna] = df_imp.at[linha, coluna]
        real_rows, imp_rows = [], []
        for linha in real_dict.keys():
            row_real = {}
            row_imp = {}
            for col in col_continuas + cols_categoricas:
                if col in real_dict[linha]:
                    row_real[col] = real_dict[linha][col]
                    row_imp[col] = imp_dict[linha][col]
                else:
                    row_real[col] = df_original_clean.at[linha, col]
                    row_imp[col] = df_original_clean.at[linha, col]
            real_rows.append(row_real)
            imp_rows.append(row_imp)
        df_real_gower = pd.DataFrame(real_rows)
        df_imp_gower = pd.DataFrame(imp_rows)
        gower_list.append(gower_distance_matrix(df_real_gower, df_imp_gower, col_continuas, cols_categoricas))

    # Agregação
    if use_conditional_mean:
        metricas_cat = {
            'acuracia': acc_list[0] if acc_list else np.nan,
            'precisao': prec_list[0] if prec_list else np.nan,
            'recall': rec_list[0] if rec_list else np.nan,
            'f1_score': f1_list[0] if f1_list else np.nan,
            'kappa': kappa_list[0] if kappa_list else np.nan,
            'mcc': mcc_list[0] if mcc_list else np.nan,
            'erro_correlacao': erro_cor_list[0] if erro_cor_list else np.nan,
            'gower_distance': gower_list[0] if gower_list else np.nan
        }
        smae_cat_col_means = {col: np.mean(smae_cat_por_coluna.get(col, [])) if smae_cat_por_coluna.get(col) else np.nan for col in col_ordinais_smae}
        metricas_cat['smae_medio'] = np.nanmean(list(smae_cat_col_means.values()))

        metricas_cont = {}
        for col in col_continuas:
            metricas_cont[col] = {met: dict_cont[col][met][0] if dict_cont[col][met] else np.nan for met in dict_cont[col]}
        smae_cont_col_means = {col: np.mean(smae_cont_por_coluna.get(col, [])) if smae_cont_por_coluna.get(col) else np.nan for col in col_continuas_smae}
        metricas_cont['smae_medio'] = np.nanmean(list(smae_cont_col_means.values()))
        # Agregados
        metricas_cont['nrmse_medio'] = np.mean([dict_cont[col]['nrmse'][0] for col in col_continuas if dict_cont[col]['nrmse']]) if any(dict_cont[col]['nrmse'] for col in col_continuas) else np.nan
        metricas_cont['nmae_medio'] = np.mean([dict_cont[col]['nmae'][0] for col in col_continuas if dict_cont[col]['nmae']]) if any(dict_cont[col]['nmae'] for col in col_continuas) else np.nan
        metricas_cont['mape_medio'] = np.mean([dict_cont[col]['mape'][0] for col in col_continuas if dict_cont[col]['mape']]) if any(dict_cont[col]['mape'] for col in col_continuas) else np.nan
        metricas_cont['smape_medio'] = np.mean([dict_cont[col]['smape'][0] for col in col_continuas if dict_cont[col]['smape']]) if any(dict_cont[col]['smape'] for col in col_continuas) else np.nan
        metricas_cont['r2_medio'] = np.mean([dict_cont[col]['r2'][0] for col in col_continuas if dict_cont[col]['r2']]) if any(dict_cont[col]['r2'] for col in col_continuas) else np.nan

        metricas_cat_rubin = {k: {'Q_bar': v, 'ci_lower': np.nan, 'ci_upper': np.nan} for k, v in metricas_cat.items()}
        metricas_cont_rubin = {}
        for k, v in metricas_cont.items():
            if isinstance(v, dict):
                metricas_cont_rubin[k] = {kk: vv for kk, vv in v.items()}
            else:
                metricas_cont_rubin[k] = {'Q_bar': v, 'ci_lower': np.nan, 'ci_upper': np.nan}
        return dict(datasets=datasets, metricas_cat=metricas_cat_rubin, metricas_cont=metricas_cont_rubin)
    else:
        # Múltiplas imputações com Rubin
        metricas_cat = {}
        for nome, lst in [('acuracia', acc_list), ('precisao', prec_list), ('recall', rec_list),
                          ('f1_score', f1_list), ('kappa', kappa_list), ('mcc', mcc_list)]:
            metricas_cat[nome] = rubin_pool(lst, n_imp, ALPHA) if lst else {'Q_bar': np.nan, 'ci_lower': np.nan, 'ci_upper': np.nan}
        metricas_cat['erro_correlacao'] = rubin_pool(erro_cor_list, n_imp, ALPHA) if erro_cor_list else {'Q_bar': np.nan, 'ci_lower': np.nan, 'ci_upper': np.nan}
        metricas_cat['gower_distance'] = rubin_pool(gower_list, n_imp, ALPHA) if gower_list else {'Q_bar': np.nan, 'ci_lower': np.nan, 'ci_upper': np.nan}
        smae_cat_col_means = {col: np.mean(smae_cat_por_coluna.get(col, [])) if smae_cat_por_coluna.get(col) else np.nan for col in col_ordinais_smae}
        smae_cat_final = np.nanmean(list(smae_cat_col_means.values()))
        metricas_cat['smae_medio'] = {'Q_bar': smae_cat_final, 'ci_lower': np.nan, 'ci_upper': np.nan}

        metricas_cont = {}
        for col in col_continuas:
            metricas_cont[col] = {met: rubin_pool(dict_cont[col][met], n_imp, ALPHA) if dict_cont[col][met] else {'Q_bar': np.nan, 'ci_lower': np.nan, 'ci_upper': np.nan} for met in dict_cont[col]}
        smae_cont_col_means = {col: np.mean(smae_cont_por_coluna.get(col, [])) if smae_cont_por_coluna.get(col) else np.nan for col in col_continuas_smae}
        smae_cont_final = np.nanmean(list(smae_cont_col_means.values()))
        metricas_cont['smae_medio'] = {'Q_bar': smae_cont_final, 'ci_lower': np.nan, 'ci_upper': np.nan}

        # Agregados com Rubin
        nrmse_vals = [dict_cont[col]['nrmse'] for col in col_continuas if dict_cont[col]['nrmse']]
        nmae_vals = [dict_cont[col]['nmae'] for col in col_continuas if dict_cont[col]['nmae']]
        mape_vals = [dict_cont[col]['mape'] for col in col_continuas if dict_cont[col]['mape']]
        smape_vals = [dict_cont[col]['smape'] for col in col_continuas if dict_cont[col]['smape']]
        r2_vals = [dict_cont[col]['r2'] for col in col_continuas if dict_cont[col]['r2']]
        metricas_cont['nrmse_medio'] = rubin_pool([v for sub in nrmse_vals for v in sub], n_imp, ALPHA) if nrmse_vals else {'Q_bar': np.nan, 'ci_lower': np.nan, 'ci_upper': np.nan}
        metricas_cont['nmae_medio'] = rubin_pool([v for sub in nmae_vals for v in sub], n_imp, ALPHA) if nmae_vals else {'Q_bar': np.nan, 'ci_lower': np.nan, 'ci_upper': np.nan}
        metricas_cont['mape_medio'] = rubin_pool([v for sub in mape_vals for v in sub], n_imp, ALPHA) if mape_vals else {'Q_bar': np.nan, 'ci_lower': np.nan, 'ci_upper': np.nan}
        metricas_cont['smape_medio'] = rubin_pool([v for sub in smape_vals for v in sub], n_imp, ALPHA) if smape_vals else {'Q_bar': np.nan, 'ci_lower': np.nan, 'ci_upper': np.nan}
        metricas_cont['r2_medio'] = rubin_pool([v for sub in r2_vals for v in sub], n_imp, ALPHA) if r2_vals else {'Q_bar': np.nan, 'ci_lower': np.nan, 'ci_upper': np.nan}

        return dict(datasets=datasets, metricas_cat=metricas_cat, metricas_cont=metricas_cont)

# ============================================================================
# BLOCO 7: BOOTSTRAP EXTERNO
# ============================================================================

def bootstrap_misto(df_cod, proporcao_missing, col_continuas, col_ordinais, col_nominais,
                    indices_continuas, indices_ordinais,
                    B=BOOTSTRAP_ITERACOES, m=M_IMPUTATIONS, random_seed=RANDOM_SEED,
                    verbose_first=True, use_conditional_mean=False):
    resultados_bootstrap_cat = []
    resultados_bootstrap_cont = []
    tempos_iteracao = []

    for b in range(1, B+1):
        display(HTML(f'<div class="metrics-highlight">🔷 BOOTSTRAP {b}/{B} - Proporção missing: {proporcao_missing*100:.0f}%</div>'))
        start_iter = time.time()
        rng = np.random.default_rng(random_seed + b)
        idx_boot = rng.choice(df_cod.index, size=len(df_cod), replace=True)
        df_boot_clean = df_cod.loc[idx_boot].reset_index(drop=True)
        df_na, pos_orig = criar_missing_mcar_estratificado(df_boot_clean, proporcao_missing, random_seed=random_seed + b*100)
        show_prog = (verbose_first and b == 1)
        out = multiple_imputation_rubin_misto(
            df_na, pos_orig, df_boot_clean,
            col_continuas, col_ordinais, col_nominais,
            indices_continuas, indices_ordinais,
            m=m, random_seed=random_seed + b*1000, show_progress=show_prog,
            use_conditional_mean=use_conditional_mean)
        cat = out['metricas_cat']
        cont = out['metricas_cont']

        acc = cat.get('acuracia', {}).get('Q_bar', np.nan)
        prec = cat.get('precisao', {}).get('Q_bar', np.nan)
        rec = cat.get('recall', {}).get('Q_bar', np.nan)
        f1 = cat.get('f1_score', {}).get('Q_bar', np.nan)
        kappa = cat.get('kappa', {}).get('Q_bar', np.nan)
        mcc = cat.get('mcc', {}).get('Q_bar', np.nan)
        err_cor = cat.get('erro_correlacao', {}).get('Q_bar', np.nan)
        smae_cat = cat.get('smae_medio', {}).get('Q_bar', np.nan)
        smae_cont = cont.get('smae_medio', {}).get('Q_bar', np.nan)
        gower = cat.get('gower_distance', {}).get('Q_bar', np.nan)
        nrmse = cont.get('nrmse_medio', {}).get('Q_bar', np.nan)
        nmae = cont.get('nmae_medio', {}).get('Q_bar', np.nan)
        mape = cont.get('mape_medio', {}).get('Q_bar', np.nan)
        smape = cont.get('smape_medio', {}).get('Q_bar', np.nan)
        r2 = cont.get('r2_medio', {}).get('Q_bar', np.nan)

        metricas_nomes = ['rmse','mae','mse','cor','nrmse','nmae','mape','smape','r2']
        cont_vals = {}
        for met in metricas_nomes:
            if met in ['nrmse', 'nmae', 'mape', 'smape', 'r2']:
                val = cont.get(f'{met}_medio', {}).get('Q_bar', np.nan)
                vals = [val] if not np.isnan(val) else []
            else:
                vals = []
                for col in col_continuas:
                    if col in cont and met in cont[col]:
                        val = cont[col][met]
                        if isinstance(val, dict):
                            qbar = val.get('Q_bar', np.nan)
                        else:
                            qbar = val if isinstance(val, (int, float)) else np.nan
                        if not np.isnan(qbar):
                            vals.append(qbar)
            cont_vals[met] = np.mean(vals) if vals else np.nan

        elapsed = time.time() - start_iter
        tempos_iteracao.append(elapsed)

        display(HTML(f'''
        <div style="display: grid; grid-template-columns: repeat(5, 1fr); gap: 10px; margin: 10px 0;">
            <div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
                <div style="font-size: 12px;">🎯 Acurácia</div>
                <div style="font-size: 20px; font-weight: bold;">{acc:.2%}</div>
            </div>
            <div style="background: linear-gradient(135deg, #f093fb 0%, #f5576c 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
                <div style="font-size: 12px;">⚖️ F1</div>
                <div style="font-size: 20px; font-weight: bold;">{f1:.2%}</div>
            </div>
            <div style="background: linear-gradient(135deg, #4facfe 0%, #00f2fe 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
                <div style="font-size: 12px;">📈 Gower</div>
                <div style="font-size: 20px; font-weight: bold;">{gower:.3f}</div>
            </div>
            <div style="background: linear-gradient(135deg, #11998e 0%, #38ef7d 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
                <div style="font-size: 12px;">📏 NRMSE</div>
                <div style="font-size: 20px; font-weight: bold;">{nrmse:.3f}</div>
            </div>
            <div style="background: linear-gradient(135deg, #ff6b6b 0%, #ee5a24 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
                <div style="font-size: 12px;">📐 R²</div>
                <div style="font-size: 20px; font-weight: bold;">{r2:.3f}</div>
            </div>
        </div>
        <div class="info-box">
            ⏱️ Tempo: {elapsed:.2f} segundos |
            RMSE: {cont_vals['rmse']:.3f} | MAE: {cont_vals['mae']:.3f} | NMAE: {cont_vals['nmae']:.4f} |
            MAPE: {cont_vals['mape']:.2f}% | sMAPE: {cont_vals['smape']:.2f}% | Corr: {cont_vals['cor']:.3f} |
            SMAE_Cont: {smae_cont:.3f} | SMAE_Cat: {smae_cat:.3f} | Erro Corr: {err_cor:.4f}
        </div>
        '''))

        resultados_bootstrap_cat.append(dict(
            bootstrap_id=b, acuracia=acc, precisao=prec, recall=rec,
            f1_score=f1, kappa=kappa, mcc=mcc, erro_correlacao=err_cor,
            smae_cat=smae_cat, smae_cont=smae_cont, gower_distance=gower))
        temp_cont = {'bootstrap_id': b}
        temp_cont.update({f'{met}_medio': cont_vals[met] for met in metricas_nomes})
        resultados_bootstrap_cont.append(temp_cont)

    def bootstrap_stats(arr):
        arr = np.array(arr, dtype=float)
        arr = arr[~np.isnan(arr)]
        if len(arr) == 0:
            return dict(media=np.nan, ic_inf=np.nan, ic_sup=np.nan)
        return dict(media=np.mean(arr), ic_inf=np.percentile(arr, 2.5), ic_sup=np.percentile(arr, 97.5))

    df_cat = pd.DataFrame(resultados_bootstrap_cat)
    estat_cat = {met: bootstrap_stats(df_cat[met].values) for met in ['acuracia','precisao','recall','f1_score','kappa','mcc','erro_correlacao','smae_cat','smae_cont','gower_distance']}
    df_cont = pd.DataFrame(resultados_bootstrap_cont)
    estat_cont = {met: bootstrap_stats(df_cont[met].values) for met in df_cont.columns if met != 'bootstrap_id'}
    return dict(estat_cat=estat_cat, estat_cont=estat_cont, tempo_medio=np.mean(tempos_iteracao))

# ============================================================================
# BLOCO 8: EXECUÇÃO PRINCIPAL
# ============================================================================

if __name__ == "__main__":
    display(HTML('<div class="header">🚀 INÍCIO DA EXECUÇÃO - GAUSSIAN COPULA + RUBIN (TIPS 2 CONTÍNUAS + 5 ORDINAIS)</div>'))
    display(HTML(f'<div class="info-box">📅 Data/Hora: {time.strftime("%Y-%m-%d %H:%M:%S")}</div>'))

    USE_CONDITIONAL_MEAN = True
    proporcoes = [0.15, 0.30, 0.40, 0.60, 0.75, 0.90]
    tabela_cat_rows, tabela_cont_rows, tempos_exec = [], [], []

    for idx_prop, prop in enumerate(proporcoes, start=1):
        display(HTML(f'<div class="header">🎯 PROPORÇÃO {idx_prop}/{len(proporcoes)}: {prop*100:.0f}% de missing</div>'))
        inicio = time.time()
        boot_out = bootstrap_misto(
            df_cod, prop, col_continuas, col_ordinais, col_nominais,
            indices_continuas, indices_ordinais,
            B=BOOTSTRAP_ITERACOES, m=M_IMPUTATIONS, random_seed=RANDOM_SEED,
            verbose_first=(prop == proporcoes[0]),
            use_conditional_mean=USE_CONDITIONAL_MEAN
        )
        fim = time.time()
        tempo_total = fim - inicio
        display(HTML(f'<div class="success-box">✅ Proporção {prop*100:.0f}% concluída em {tempo_total:.2f} segundos.</div>'))

        cat = boot_out['estat_cat']
        tabela_cat_rows.append({
            'Missing': f"{prop*100:.0f}%",
            'Acurácia': f"{cat['acuracia']['media']*100:.2f}%",
            'IC_Acurácia': f"[{cat['acuracia']['ic_inf']*100:.2f}%, {cat['acuracia']['ic_sup']*100:.2f}%]",
            'Precisão': f"{cat['precisao']['media']*100:.2f}%",
            'IC_Precisão': f"[{cat['precisao']['ic_inf']*100:.2f}%, {cat['precisao']['ic_sup']*100:.2f}%]",
            'Recall': f"{cat['recall']['media']*100:.2f}%",
            'IC_Recall': f"[{cat['recall']['ic_inf']*100:.2f}%, {cat['recall']['ic_sup']*100:.2f}%]",
            'F1': f"{cat['f1_score']['media']*100:.2f}%",
            'IC_F1': f"[{cat['f1_score']['ic_inf']*100:.2f}%, {cat['f1_score']['ic_sup']*100:.2f}%]",
            'Kappa': f"{cat['kappa']['media']:.3f}",
            'IC_Kappa': f"[{cat['kappa']['ic_inf']:.3f}, {cat['kappa']['ic_sup']:.3f}]",
            'MCC': f"{cat['mcc']['media']:.3f}",
            'IC_MCC': f"[{cat['mcc']['ic_inf']:.3f}, {cat['mcc']['ic_sup']:.3f}]",
            'Erro_Correlação': f"{cat['erro_correlacao']['media']:.4f}",
            'IC_ErroCor': f"[{cat['erro_correlacao']['ic_inf']:.4f}, {cat['erro_correlacao']['ic_sup']:.4f}]",
            'SMAE_Categórico': f"{cat['smae_cat']['media']:.3f}",
            'IC_SMAE_Cat': f"[{cat['smae_cat']['ic_inf']:.3f}, {cat['smae_cat']['ic_sup']:.3f}]",
            'SMAE_Contínuo': f"{cat['smae_cont']['media']:.3f}",
            'IC_SMAE_Cont': f"[{cat['smae_cont']['ic_inf']:.3f}, {cat['smae_cont']['ic_sup']:.3f}]",
            'Gower_Distance': f"{cat['gower_distance']['media']:.4f}",
            'IC_Gower': f"[{cat['gower_distance']['ic_inf']:.4f}, {cat['gower_distance']['ic_sup']:.4f}]"
        })

        cont = boot_out['estat_cont']
        tabela_cont_rows.append({
            'Missing': f"{prop*100:.0f}%",
            'RMSE': f"{cont['rmse_medio']['media']:.3f}",
            'IC_RMSE': f"[{cont['rmse_medio']['ic_inf']:.3f}, {cont['rmse_medio']['ic_sup']:.3f}]",
            'MAE': f"{cont['mae_medio']['media']:.3f}",
            'IC_MAE': f"[{cont['mae_medio']['ic_inf']:.3f}, {cont['mae_medio']['ic_sup']:.3f}]",
            'NMAE': f"{cont['nmae_medio']['media']:.4f}",
            'IC_NMAE': f"[{cont['nmae_medio']['ic_inf']:.4f}, {cont['nmae_medio']['ic_sup']:.4f}]",
            'MSE': f"{cont['mse_medio']['media']:.3f}",
            'IC_MSE': f"[{cont['mse_medio']['ic_inf']:.3f}, {cont['mse_medio']['ic_sup']:.3f}]",
            'MAPE(%)': f"{cont['mape_medio']['media']:.2f}",
            'IC_MAPE': f"[{cont['mape_medio']['ic_inf']:.2f}, {cont['mape_medio']['ic_sup']:.2f}]",
            'sMAPE(%)': f"{cont['smape_medio']['media']:.2f}",
            'IC_sMAPE': f"[{cont['smape_medio']['ic_inf']:.2f}, {cont['smape_medio']['ic_sup']:.2f}]",
            'Correlação': f"{cont['cor_medio']['media']:.3f}",
            'IC_Cor': f"[{cont['cor_medio']['ic_inf']:.3f}, {cont['cor_medio']['ic_sup']:.3f}]",
            'NRMSE': f"{cont['nrmse_medio']['media']:.4f}",
            'IC_NRMSE': f"[{cont['nrmse_medio']['ic_inf']:.4f}, {cont['nrmse_medio']['ic_sup']:.4f}]",
            'R²': f"{cont['r2_medio']['media']:.4f}",
            'IC_R²': f"[{cont['r2_medio']['ic_inf']:.4f}, {cont['r2_medio']['ic_sup']:.4f}]"
        })

        tempos_exec.append({
            'Proporção': f"{prop*100:.0f}%",
            'Tempo_Total': f"{tempo_total:.2f}",
            'Tempo_Medio_Boot': f"{boot_out['tempo_medio']:.2f}"
        })

    display(HTML('<div class="header">📊 RESULTADOS FINAIS - VARIÁVEIS ORDINAIS (size, day, time, smoker, sex)</div>'))
    df_cat_final = pd.DataFrame(tabela_cat_rows)
    display(df_cat_final.style.set_table_attributes('class="dataframe-table"'))

    display(HTML('<div class="header">📊 RESULTADOS FINAIS - VARIÁVEIS CONTÍNUAS (total_bill, tip)</div>'))
    df_cont_final = pd.DataFrame(tabela_cont_rows)
    display(df_cont_final.style.set_table_attributes('class="dataframe-table"'))

    display(HTML('<div class="header">⏱️ TEMPOS DE EXECUÇÃO POR PROPORÇÃO</div>'))
    df_tempo = pd.DataFrame(tempos_exec)
    display(df_tempo.style.set_table_attributes('class="dataframe-table"'))

    try:
        df_plot = pd.DataFrame(tabela_cat_rows)
        df_plot['prop'] = df_plot['Missing'].str.replace('%','').astype(float)/100
        df_plot['Acc'] = df_plot['Acurácia'].str.replace('%','').astype(float)/100
        plt.figure(figsize=(8,5))
        sns.lineplot(x='prop', y='Acc', data=df_plot, marker='o', color='blue')
        plt.xlabel("Proporção de missing")
        plt.ylabel("Acurácia")
        plt.title("Acurácia por proporção de dados faltantes - Dataset Tips (2 cont, 5 ord)")
        plt.grid(True, linestyle='--', alpha=0.7)
        plt.show()
    except Exception as e:
        display(HTML(f'<div class="warning-box">⚠️ Gráfico não pôde ser gerado: {e}</div>'))

    display(HTML('<div class="success-box">🎉 EXECUÇÃO CONCLUÍDA - TIPS COM 2 CONTÍNUAS E 5 ORDINAIS!</div>'))
# Out:
# <style>
#     .header {
#         background: linear-gradient(135deg, #667eea 0%, #764ba2 100%);
#         color: white;
#         padding: 15px;
#         border-radius: 10px;
#         margin: 10px 0;
#         text-align: center;
#         font-family: Arial, sans-serif;
#         font-weight: bold;
#         font-size: 18px;
#     }
#     .success-box {
#         background-color: #d4edda;
#         color: #155724;
#         padding: 12px;
#         border: 1px solid #c3e6cb;
#         border-radius: 5px;
#         margin: 10px 0;
#         font-weight: bold;
#     }
#     .warning-box {
#         background-color: #fff3cd;
#         color: #856404;
#         padding: 12px;
#         border: 1px solid #ffeaa7;
#         border-radius: 5px;
#         margin: 10px 0;
#         font-weight: bold;
#     }
#     .info-box {
#         background-color: #d1ecf1;
#         color: #0c5460;
#         padding: 12px;
#         border: 1px solid #bee5eb;
#         border-radius: 5px;
#         margin: 10px 0;
#     }
#     .metrics-highlight {
#         background: linear-gradient(135deg, #ffd89b 0%, #19547b 100%);
#         color: white;
#         padding: 15px;
#         border-radius: 10px;
#         margin: 10px 0;
#         text-align: center;
#         font-weight: bold;
#     }
#     .dataframe-table {
#         font-family: Arial, sans-serif;
#         border-collapse: collapse;
#         width: 100%;
#         box-shadow: 0 4px 8px rgba(0,0,0,0.1);
#         border-radius: 10px;
#         overflow: hidden;
#         margin: 20px 0;
#     }
#     .dataframe-table th {
#         background: linear-gradient(135deg, #2c3e50 0%, #3498db 100%);
#         color: white;
#         padding: 12px;
#         text-align: left;
#         font-weight: bold;
#     }
#     .dataframe-table td {
#         padding: 10px;
#         border-bottom: 1px solid #ddd;
#     }
#     .dataframe-table tr:nth-child(even) {
#         background-color: #f8f9fa;
#     }
#     .dataframe-table tr:hover {
#         background-color: #e9ecef;
#         transform: scale(1.01);
#         transition: all 0.2s ease;
#     }
#     .rubin-rules-box {
#         background: linear-gradient(135deg, #667eea 0%, #764ba2 100%);
#         color: white;
#         padding: 15px;
#         border-radius: 10px;
#         margin: 10px 0;
#         text-align: center;
#         font-weight: bold;
#     }
#     .iteration-box {
#         background-color: #e8f4fd;
#         border-left: 5px solid #3498db;
#         padding: 10px;
#         margin: 10px 0;
#         border-radius: 5px;
#     }
#     .encoding-badge {
#         background: linear-gradient(135deg, #f093fb 0%, #f5576c 100%);
#         color: white;
#         padding: 5px 10px;
#         border-radius: 15px;
#         font-size: 12px;
#         font-weight: bold;
#         display: inline-block;
#         margin: 2px;
#     }
# </style>
# Instalando gcimpute do GitHub...
# <div class="header">🍽️ CARREGANDO DATASET TIPS (2 contínuas, 5 ordinais)</div>
# <div class="success-box">✅ Dados carregados: 244 linhas, 7 colunas.</div>
# <div class="info-box"><b>Primeiras linhas:</b></div>
# <style type="text/css">
# </style>
# <table id="T_a12cf" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a12cf_level0_col0" class="col_heading level0 col0" >total_bill</th>
#       <th id="T_a12cf_level0_col1" class="col_heading level0 col1" >tip</th>
#       <th id="T_a12cf_level0_col2" class="col_heading level0 col2" >sex</th>
#       <th id="T_a12cf_level0_col3" class="col_heading level0 col3" >smoker</th>
#       <th id="T_a12cf_level0_col4" class="col_heading level0 col4" >day</th>
#       <th id="T_a12cf_level0_col5" class="col_heading level0 col5" >time</th>
#       <th id="T_a12cf_level0_col6" class="col_heading level0 col6" >size</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a12cf_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a12cf_row0_col0" class="data row0 col0" >16.990000</td>
#       <td id="T_a12cf_row0_col1" class="data row0 col1" >1.010000</td>
#       <td id="T_a12cf_row0_col2" class="data row0 col2" >Female</td>
#       <td id="T_a12cf_row0_col3" class="data row0 col3" >No</td>
#       <td id="T_a12cf_row0_col4" class="data row0 col4" >Sun</td>
#       <td id="T_a12cf_row0_col5" class="data row0 col5" >Dinner</td>
#       <td id="T_a12cf_row0_col6" class="data row0 col6" >2</td>
#     </tr>
#     <tr>
#       <th id="T_a12cf_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a12cf_row1_col0" class="data row1 col0" >10.340000</td>
#       <td id="T_a12cf_row1_col1" class="data row1 col1" >1.660000</td>
#       <td id="T_a12cf_row1_col2" class="data row1 col2" >Male</td>
#       <td id="T_a12cf_row1_col3" class="data row1 col3" >No</td>
#       <td id="T_a12cf_row1_col4" class="data row1 col4" >Sun</td>
#       <td id="T_a12cf_row1_col5" class="data row1 col5" >Dinner</td>
#       <td id="T_a12cf_row1_col6" class="data row1 col6" >3</td>
#     </tr>
#     <tr>
#       <th id="T_a12cf_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a12cf_row2_col0" class="data row2 col0" >21.010000</td>
#       <td id="T_a12cf_row2_col1" class="data row2 col1" >3.500000</td>
#       <td id="T_a12cf_row2_col2" class="data row2 col2" >Male</td>
#       <td id="T_a12cf_row2_col3" class="data row2 col3" >No</td>
#       <td id="T_a12cf_row2_col4" class="data row2 col4" >Sun</td>
#       <td id="T_a12cf_row2_col5" class="data row2 col5" >Dinner</td>
#       <td id="T_a12cf_row2_col6" class="data row2 col6" >3</td>
#     </tr>
#     <tr>
#       <th id="T_a12cf_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a12cf_row3_col0" class="data row3 col0" >23.680000</td>
#       <td id="T_a12cf_row3_col1" class="data row3 col1" >3.310000</td>
#       <td id="T_a12cf_row3_col2" class="data row3 col2" >Male</td>
#       <td id="T_a12cf_row3_col3" class="data row3 col3" >No</td>
#       <td id="T_a12cf_row3_col4" class="data row3 col4" >Sun</td>
#       <td id="T_a12cf_row3_col5" class="data row3 col5" >Dinner</td>
#       <td id="T_a12cf_row3_col6" class="data row3 col6" >2</td>
#     </tr>
#     <tr>
#       <th id="T_a12cf_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a12cf_row4_col0" class="data row4 col0" >24.590000</td>
#       <td id="T_a12cf_row4_col1" class="data row4 col1" >3.610000</td>
#       <td id="T_a12cf_row4_col2" class="data row4 col2" >Female</td>
#       <td id="T_a12cf_row4_col3" class="data row4 col3" >No</td>
#       <td id="T_a12cf_row4_col4" class="data row4 col4" >Sun</td>
#       <td id="T_a12cf_row4_col5" class="data row4 col5" >Dinner</td>
#       <td id="T_a12cf_row4_col6" class="data row4 col6" >4</td>
#     </tr>
#   </tbody>
# </table>
# <div class="info-box"><b>Níveis das variáveis ordinais (com ordem):</b></div>
# <span class="encoding-badge">size: [1, 2, 3, 4, 5, 6]</span>
# <span class="encoding-badge">day: ['Thur', 'Fri', 'Sat', 'Sun']</span>
# <span class="encoding-badge">time: ['Lunch', 'Dinner']</span>
# <span class="encoding-badge">smoker: ['No', 'Yes']</span>
# <span class="encoding-badge">sex: ['Female', 'Male']</span>
# <div class="info-box"><b>Dados codificados (head):</b></div>
# <style type="text/css">
# </style>
# <table id="T_7d474" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7d474_level0_col0" class="col_heading level0 col0" >total_bill</th>
#       <th id="T_7d474_level0_col1" class="col_heading level0 col1" >tip</th>
#       <th id="T_7d474_level0_col2" class="col_heading level0 col2" >sex</th>
#       <th id="T_7d474_level0_col3" class="col_heading level0 col3" >smoker</th>
#       <th id="T_7d474_level0_col4" class="col_heading level0 col4" >day</th>
#       <th id="T_7d474_level0_col5" class="col_heading level0 col5" >time</th>
#       <th id="T_7d474_level0_col6" class="col_heading level0 col6" >size</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7d474_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7d474_row0_col0" class="data row0 col0" >16.990000</td>
#       <td id="T_7d474_row0_col1" class="data row0 col1" >1.010000</td>
#       <td id="T_7d474_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_7d474_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_7d474_row0_col4" class="data row0 col4" >3</td>
#       <td id="T_7d474_row0_col5" class="data row0 col5" >1</td>
#       <td id="T_7d474_row0_col6" class="data row0 col6" >1</td>
#     </tr>
#     <tr>
#       <th id="T_7d474_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7d474_row1_col0" class="data row1 col0" >10.340000</td>
#       <td id="T_7d474_row1_col1" class="data row1 col1" >1.660000</td>
#       <td id="T_7d474_row1_col2" class="data row1 col2" >1</td>
#       <td id="T_7d474_row1_col3" class="data row1 col3" >0</td>
#       <td id="T_7d474_row1_col4" class="data row1 col4" >3</td>
#       <td id="T_7d474_row1_col5" class="data row1 col5" >1</td>
#       <td id="T_7d474_row1_col6" class="data row1 col6" >2</td>
#     </tr>
#     <tr>
#       <th id="T_7d474_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7d474_row2_col0" class="data row2 col0" >21.010000</td>
#       <td id="T_7d474_row2_col1" class="data row2 col1" >3.500000</td>
#       <td id="T_7d474_row2_col2" class="data row2 col2" >1</td>
#       <td id="T_7d474_row2_col3" class="data row2 col3" >0</td>
#       <td id="T_7d474_row2_col4" class="data row2 col4" >3</td>
#       <td id="T_7d474_row2_col5" class="data row2 col5" >1</td>
#       <td id="T_7d474_row2_col6" class="data row2 col6" >2</td>
#     </tr>
#     <tr>
#       <th id="T_7d474_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7d474_row3_col0" class="data row3 col0" >23.680000</td>
#       <td id="T_7d474_row3_col1" class="data row3 col1" >3.310000</td>
#       <td id="T_7d474_row3_col2" class="data row3 col2" >1</td>
#       <td id="T_7d474_row3_col3" class="data row3 col3" >0</td>
#       <td id="T_7d474_row3_col4" class="data row3 col4" >3</td>
#       <td id="T_7d474_row3_col5" class="data row3 col5" >1</td>
#       <td id="T_7d474_row3_col6" class="data row3 col6" >1</td>
#     </tr>
#     <tr>
#       <th id="T_7d474_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7d474_row4_col0" class="data row4 col0" >24.590000</td>
#       <td id="T_7d474_row4_col1" class="data row4 col1" >3.610000</td>
#       <td id="T_7d474_row4_col2" class="data row4 col2" >0</td>
#       <td id="T_7d474_row4_col3" class="data row4 col3" >0</td>
#       <td id="T_7d474_row4_col4" class="data row4 col4" >3</td>
#       <td id="T_7d474_row4_col5" class="data row4 col5" >1</td>
#       <td id="T_7d474_row4_col6" class="data row4 col6" >3</td>
#     </tr>
#   </tbody>
# </table>
# Índices contínuas: [0, 1]
# Índices ordinais : [6, 4, 5, 3, 2]
# <div class="header">🚀 INÍCIO DA EXECUÇÃO - GAUSSIAN COPULA + RUBIN (TIPS 2 CONTÍNUAS + 5 ORDINAIS)</div>
# <div class="info-box">📅 Data/Hora: 2026-05-19 17:38:14</div>
# <div class="header">🎯 PROPORÇÃO 1/6: 15% de missing</div>
# <div class="metrics-highlight">🔷 BOOTSTRAP 1/100 - Proporção missing: 15%</div>
# <div class="iteration-box">🔹 Gerando imputação por média condicional...</div>
#   Ajustando Gaussian Copula (EM)...
#     contínuas: [0, 1]
#     ordinais : [6, 4, 5, 3, 2]
# Iter 1: copula parameter change 0.0955, likelihood -7.5901
# Iter 2: copula parameter change 0.0398, likelihood -7.4645
# Iter 3: copula parameter change 0.0215, likelihood -7.3958
# Iter 4: copula parameter change 0.0120, likelihood -7.3501
# Iter 5: copula parameter change 0.0077, likelihood -7.3219
# Iter 6: copula parameter change 0.0050, likelihood -7.3034
# Iter 7: copula parameter change 0.0035, likelihood -7.2916
# Iter 8: copula parameter change 0.0025, likelihood -7.2837
# Iter 9: copula parameter change 0.0019, likelihood -7.2784
# Iter 10: copula parameter change 0.0014, likelihood -7.2749
# Iter 11: copula parameter change 0.0010, likelihood -7.2725
# Iter 12: copula parameter change 0.0008, likelihood -7.2708
# Convergence achieved at iteration 12
# <div class="metrics-highlight">📊 Avaliando imputação 1/1</div>
#         <div style="display: grid; grid-template-columns: repeat(5, 1fr); gap: 10px; margin: 10px 0;">
#             <div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">🎯 Acurácia</div>
#                 <div style="font-size: 20px; font-weight: bold;">72.78%</div>
#             </div>
#             <div style="background: linear-gradient(135deg, #f093fb 0%, #f5576c 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">⚖️ F1</div>
#                 <div style="font-size: 20px; font-weight: bold;">42.96%</div>
#             </div>
#             <div style="background: linear-gradient(135deg, #4facfe 0%, #00f2fe 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">📈 Gower</div>
#                 <div style="font-size: 20px; font-weight: bold;">0.053</div>
#             </div>
#             <div style="background: linear-gradient(135deg, #11998e 0%, #38ef7d 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">📏 NRMSE</div>
#                 <div style="font-size: 20px; font-weight: bold;">0.167</div>
#             </div>
#             <div style="background: linear-gradient(135deg, #ff6b6b 0%, #ee5a24 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">📐 R²</div>
#                 <div style="font-size: 20px; font-weight: bold;">0.172</div>
#             </div>
#         </div>
#         <div class="info-box">
#             ⏱️ Tempo: 1.61 segundos |
#             RMSE: 4.496 | MAE: 3.001 | NMAE: 0.1075 |
#             MAPE: 36.11% | sMAPE: 30.34% | Corr: 0.484 |
#             SMAE_Cont: 0.860 | SMAE_Cat: 0.601 | Erro Corr: 0.0195
#         </div>
# <div class="metrics-highlight">🔷 BOOTSTRAP 2/100 - Proporção missing: 15%</div>
#         <div style="display: grid; grid-template-columns: repeat(5, 1fr); gap: 10px; margin: 10px 0;">
#             <div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">🎯 Acurácia</div>
#                 <div style="font-size: 20px; font-weight: bold;">69.44%</div>
#             </div>
#             <div style="background: linear-gradient(135deg, #f093fb 0%, #f5576c 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">⚖️ F1</div>
#                 <div style="font-size: 20px; font-weight: bold;">40.59%</div>
#             </div>
#             <div style="background: linear-gradient(135deg, #4facfe 0%, #00f2fe 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">📈 Gower</div>
#                 <div style="font-size: 20px; font-weight: bold;">0.056</div>
#             </div>
#             <div style="background: linear-gradient(135deg, #11998e 0%, #38ef7d 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">📏 NRMSE</div>
#                 <div style="font-size: 20px; font-weight: bold;">0.175</div>
#             </div>
#             <div style="background: linear-gradient(135deg, #ff6b6b 0%, #ee5a24 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">📐 R²</div>
#                 <div style="font-size: 20px; font-weight: bold;">0.454</div>
#             </div>
#         </div>
#         <div class="info-box">
#             ⏱️ Tempo: 1.42 segundos |
#             RMSE: 2.639 | MAE: 1.882 | NMAE: 0.1274 |
#             MAPE: 23.78% | sMAPE: 21.22% | Corr: 0.760 |
#             SMAE_Cont: 0.684 | SMAE_Cat: 0.798 | Erro Corr: 0.0073
#         </div>
# <div class="metrics-highlight">🔷 BOOTSTRAP 3/100 - Proporção missing: 15%</div>
#         <div style="display: grid; grid-template-columns: repeat(5, 1fr); gap: 10px; margin: 10px 0;">
#             <div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">🎯 Acurácia</div>
#                 <div style="font-size: 20px; font-weight: bold;">63.89%</div>
#             </div>
#             <div style="background: linear-gradient(135deg, #f093fb 0%, #f5576c 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">⚖️ F1</div>
#                 <div style="font-size: 20px; font-weight: bold;">42.70%</div>
#             </div>
#             <div style="background: linear-gradient(135deg, #4facfe 0%, #00f2fe 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">📈 Gower</div>
#                 <div style="font-size: 20px; font-weight: bold;">0.063</div>
#             </div>
#             <div style="background: linear-gradient(135deg, #11998e 0%, #38ef7d 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">📏 NRMSE</div>
#                 <div style="font-size: 20px; font-weight: bold;">0.219</div>
#             </div>
#             <div style="background: linear-gradient(135deg, #ff6b6b 0%, #ee5a24 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">📐 R²</div>
#                 <div style="font-size: 20px; font-weight: bold;">0.201</div>
#             </div>
#         </div>
#         <div class="info-box">
#             ⏱️ Tempo: 1.31 segundos |
#             RMSE: 3.728 | MAE: 2.673 | NMAE: 0.1611 |
#             MAPE: 25.82% | sMAPE: 25.56% | Corr: 0.533 |
#             SMAE_Cont: 0.799 | SMAE_Cat: 0.760 | Erro Corr: 0.0544
#         </div>
# <div class="metrics-highlight">🔷 BOOTSTRAP 4/100 - Proporção missing: 15%</div>
#         <div style="display: grid; grid-template-columns: repeat(5, 1fr); gap: 10px; margin: 10px 0;">
#             <div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">🎯 Acurácia</div>
#                 <div style="font-size: 20px; font-weight: bold;">71.11%</div>
#             </div>
#             <div style="background: linear-gradient(135deg, #f093fb 0%, #f5576c 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">⚖️ F1</div>
#                 <div style="font-size: 20px; font-weight: bold;">62.14%</div>
#             </div>
#             <div style="background: linear-gradient(135deg, #4facfe 0%, #00f2fe 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">📈 Gower</div>
#                 <div style="font-size: 20px; font-weight: bold;">0.050</div>
#             </div>
#             <div style="background: linear-gradient(135deg, #11998e 0%, #38ef7d 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">📏 NRMSE</div>
#                 <div style="font-size: 20px; font-weight: bold;">0.163</div>
#             </div>
#             <div style="background: linear-gradient(135deg, #ff6b6b 0%, #ee5a24 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">📐 R²</div>
#                 <div style="font-size: 20px; font-weight: bold;">0.325</div>
#             </div>
#         </div>
#         <div class="info-box">
#             ⏱️ Tempo: 1.45 segundos |
#             RMSE: 4.282 | MAE: 2.724 | NMAE: 0.1014 |
#             MAPE: 21.98% | sMAPE: 22.37% | Corr: 0.599 |
#             SMAE_Cont: 0.711 | SMAE_Cat: 0.686 | Erro Corr: 0.0029
#         </div>
# <div class="metrics-highlight">🔷 BOOTSTRAP 5/100 - Proporção missing: 15%</div>
#         <div style="display: grid; grid-template-columns: repeat(5, 1fr); gap: 10px; margin: 10px 0;">
#             <div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">🎯 Acurácia</div>
#                 <div style="font-size: 20px; font-weight: bold;">70.00%</div>
#             </div>
#             <div style="background: linear-gradient(135deg, #f093fb 0%, #f5576c 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">⚖️ F1</div>
#                 <div style="font-size: 20px; font-weight: bold;">44.58%</div>
#             </div>
#             <div style="background: linear-gradient(135deg, #4facfe 0%, #00f2fe 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">📈 Gower</div>
#                 <div style="font-size: 20px; font-weight: bold;">0.054</div>
#             </div>
#             <div style="background: linear-gradient(135deg, #11998e 0%, #38ef7d 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">📏 NRMSE</div>
#                 <div style="font-size: 20px; font-weight: bold;">0.173</div>
#             </div>
#             <div style="background: linear-gradient(135deg, #ff6b6b 0%, #ee5a24 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">📐 R²</div>
#                 <div style="font-size: 20px; font-weight: bold;">0.377</div>
#             </div>
#         </div>
#         <div class="info-box">
#             ⏱️ Tempo: 1.83 segundos |
#             RMSE: 3.463 | MAE: 2.261 | NMAE: 0.1164 |
#             MAPE: 23.16% | sMAPE: 23.04% | Corr: 0.650 |
#             SMAE_Cont: 0.676 | SMAE_Cat: 0.777 | Erro Corr: 0.0418
#         </div>
# <div class="metrics-highlight">🔷 BOOTSTRAP 6/100 - Proporção missing: 15%</div>
#         <div style="display: grid; grid-template-columns: repeat(5, 1fr); gap: 10px; margin: 10px 0;">
#             <div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">🎯 Acurácia</div>
#                 <div style="font-size: 20px; font-weight: bold;">63.33%</div>
#             </div>
#             <div style="background: linear-gradient(135deg, #f093fb 0%, #f5576c 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">⚖️ F1</div>
#                 <div style="font-size: 20px; font-weight: bold;">31.45%</div>
#             </div>
#             <div style="background: linear-gradient(135deg, #4facfe 0%, #00f2fe 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">📈 Gower</div>
#                 <div style="font-size: 20px; font-weight: bold;">0.063</div>
#             </div>
#             <div style="background: linear-gradient(135deg, #11998e 0%, #38ef7d 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">📏 NRMSE</div>
#                 <div style="font-size: 20px; font-weight: bold;">0.168</div>
#             </div>
#             <div style="background: linear-gradient(135deg, #ff6b6b 0%, #ee5a24 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">📐 R²</div>
#                 <div style="font-size: 20px; font-weight: bold;">0.298</div>
#             </div>
#         </div>
#         <div class="info-box">
#             ⏱️ Tempo: 2.05 segundos |
#             RMSE: 3.241 | MAE: 2.388 | NMAE: 0.1186 |
#             MAPE: 25.75% | sMAPE: 22.31% | Corr: 0.573 |
#             SMAE_Cont: 0.788 | SMAE_Cat: 0.678 | Erro Corr: 0.0657
#         </div>
# <div class="metrics-highlight">🔷 BOOTSTRAP 7/100 - Proporção missing: 15%</div>
#         <div style="display: grid; grid-template-columns: repeat(5, 1fr); gap: 10px; margin: 10px 0;">
#             <div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">🎯 Acurácia</div>
#                 <div style="font-size: 20px; font-weight: bold;">70.56%</div>
#             </div>
#             <div style="background: linear-gradient(135deg, #f093fb 0%, #f5576c 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">⚖️ F1</div>
#                 <div style="font-size: 20px; font-weight: bold;">50.70%</div>
#             </div>
#             <div style="background: linear-gradient(135deg, #4facfe 0%, #00f2fe 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">📈 Gower</div>
#                 <div style="font-size: 20px; font-weight: bold;">0.053</div>
#             </div>
#             <div style="background: linear-gradient(135deg, #11998e 0%, #38ef7d 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">📏 NRMSE</div>
#                 <div style="font-size: 20px; font-weight: bold;">0.209</div>
#             </div>
#             <div style="background: linear-gradient(135deg, #ff6b6b 0%, #ee5a24 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">📐 R²</div>
#                 <div style="font-size: 20px; font-weight: bold;">0.214</div>
#             </div>
#         </div>
#         <div class="info-box">
#             ⏱️ Tempo: 1.86 segundos |
#             RMSE: 3.107 | MAE: 2.195 | NMAE: 0.1512 |
#             MAPE: 23.47% | sMAPE: 22.14% | Corr: 0.585 |
#             SMAE_Cont: 0.808 | SMAE_Cat: 0.649 | Erro Corr: 0.0445
#         </div>
# <div class="metrics-highlight">🔷 BOOTSTRAP 8/100 - Proporção missing: 15%</div>
#         <div style="display: grid; grid-template-columns: repeat(5, 1fr); gap: 10px; margin: 10px 0;">
#             <div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">🎯 Acurácia</div>
#                 <div style="font-size: 20px; font-weight: bold;">71.67%</div>
#             </div>
#             <div style="background: linear-gradient(135deg, #f093fb 0%, #f5576c 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">⚖️ F1</div>
#                 <div style="font-size: 20px; font-weight: bold;">47.35%</div>
#             </div>
#             <div style="background: linear-gradient(135deg, #4facfe 0%, #00f2fe 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">📈 Gower</div>
#                 <div style="font-size: 20px; font-weight: bold;">0.049</div>
#             </div>
#             <div style="background: linear-gradient(135deg, #11998e 0%, #38ef7d 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">📏 NRMSE</div>
#                 <div style="font-size: 20px; font-weight: bold;">0.187</div>
#             </div>
#             <div style="background: linear-gradient(135deg, #ff6b6b 0%, #ee5a24 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">📐 R²</div>
#                 <div style="font-size: 20px; font-weight: bold;">0.413</div>
#             </div>
#         </div>
#         <div class="info-box">
#             ⏱️ Tempo: 1.33 segundos |
#             RMSE: 3.247 | MAE: 2.341 | NMAE: 0.1364 |
#             MAPE: 23.88% | sMAPE: 22.43% | Corr: 0.681 |
#             SMAE_Cont: 0.707 | SMAE_Cat: 0.731 | Erro Corr: 0.0143
#         </div>
# <div class="metrics-highlight">🔷 BOOTSTRAP 9/100 - Proporção missing: 15%</div>
#         <div style="display: grid; grid-template-columns: repeat(5, 1fr); gap: 10px; margin: 10px 0;">
#             <div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">🎯 Acurácia</div>
#                 <div style="font-size: 20px; font-weight: bold;">67.78%</div>
#             </div>
#             <div style="background: linear-gradient(135deg, #f093fb 0%, #f5576c 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">⚖️ F1</div>
#                 <div style="font-size: 20px; font-weight: bold;">56.11%</div>
#             </div>
#             <div style="background: linear-gradient(135deg, #4facfe 0%, #00f2fe 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">📈 Gower</div>
#                 <div style="font-size: 20px; font-weight: bold;">0.060</div>
#             </div>
#             <div style="background: linear-gradient(135deg, #11998e 0%, #38ef7d 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">📏 NRMSE</div>
#                 <div style="font-size: 20px; font-weight: bold;">0.200</div>
#             </div>
#             <div style="background: linear-gradient(135deg, #ff6b6b 0%, #ee5a24 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">📐 R²</div>
#                 <div style="font-size: 20px; font-weight: bold;">0.367</div>
#             </div>
#         </div>
#         <div class="info-box">
#             ⏱️ Tempo: 1.41 segundos |
#             RMSE: 3.570 | MAE: 2.494 | NMAE: 0.1370 |
#             MAPE: 25.89% | sMAPE: 23.56% | Corr: 0.642 |
#             SMAE_Cont: 0.731 | SMAE_Cat: 0.872 | Erro Corr: 0.0219
#         </div>
# <div class="metrics-highlight">🔷 BOOTSTRAP 10/100 - Proporção missing: 15%</div>
#         <div style="display: grid; grid-template-columns: repeat(5, 1fr); gap: 10px; margin: 10px 0;">
#             <div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">🎯 Acurácia</div>
#                 <div style="font-size: 20px; font-weight: bold;">66.67%</div>
#             </div>
#             <div style="background: linear-gradient(135deg, #f093fb 0%, #f5576c 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">⚖️ F1</div>
#                 <div style="font-size: 20px; font-weight: bold;">48.31%</div>
#             </div>
#             <div style="background: linear-gradient(135deg, #4facfe 0%, #00f2fe 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">📈 Gower</div>
#                 <div style="font-size: 20px; font-weight: bold;">0.057</div>
#             </div>
#             <div style="background: linear-gradient(135deg, #11998e 0%, #38ef7d 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">📏 NRMSE</div>
#                 <div style="font-size: 20px; font-weight: bold;">0.166</div>
#             </div>
#             <div style="background: linear-gradient(135deg, #ff6b6b 0%, #ee5a24 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">📐 R²</div>
#                 <div style="font-size: 20px; font-weight: bold;">0.418</div>
#             </div>
#         </div>
#         <div class="info-box">
#             ⏱️ Tempo: 1.32 segundos |
#             RMSE: 3.486 | MAE: 2.493 | NMAE: 0.1210 |
#             MAPE: 23.83% | sMAPE: 23.94% | Corr: 0.693 |
#             SMAE_Cont: 0.651 | SMAE_Cat: 0.732 | Erro Corr: 0.0428
#         </div>
# <div class="metrics-highlight">🔷 BOOTSTRAP 11/100 - Proporção missing: 15%</div>
#         <div style="display: grid; grid-template-columns: repeat(5, 1fr); gap: 10px; margin: 10px 0;">
#             <div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">🎯 Acurácia</div>
#                 <div style="font-size: 20px; font-weight: bold;">68.89%</div>
#             </div>
#             <div style="background: linear-gradient(135deg, #f093fb 0%, #f5576c 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">⚖️ F1</div>
#                 <div style="font-size: 20px; font-weight: bold;">47.01%</div>
#             </div>
#             <div style="background: linear-gradient(135deg, #4facfe 0%, #00f2fe 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">📈 Gower</div>
#                 <div style="font-size: 20px; font-weight: bold;">0.055</div>
#             </div>
#             <div style="background: linear-gradient(135deg, #11998e 0%, #38ef7d 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">📏 NRMSE</div>
#                 <div style="font-size: 20px; font-weight: bold;">0.188</div>
#             </div>
#             <div style="background: linear-gradient(135deg, #ff6b6b 0%, #ee5a24 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">📐 R²</div>
#                 <div style="font-size: 20px; font-weight: bold;">0.274</div>
#             </div>
#         </div>
#         <div class="info-box">
#             ⏱️ Tempo: 1.22 segundos |
#             RMSE: 4.708 | MAE: 3.277 | NMAE: 0.1255 |
#             MAPE: 23.79% | sMAPE: 24.69% | Corr: 0.632 |
#             SMAE_Cont: 0.714 | SMAE_Cat: 0.859 | Erro Corr: 0.0176
#         </div>
# <div class="metrics-highlight">🔷 BOOTSTRAP 12/100 - Proporção missing: 15%</div>
#         <div style="display: grid; grid-template-columns: repeat(5, 1fr); gap: 10px; margin: 10px 0;">
#             <div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">🎯 Acurácia</div>
#                 <div style="font-size: 20px; font-weight: bold;">68.89%</div>
#             </div>
#             <div style="background: linear-gradient(135deg, #f093fb 0%, #f5576c 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">⚖️ F1</div>
#                 <div style="font-size: 20px; font-weight: bold;">37.55%</div>
#             </div>
#             <div style="background: linear-gradient(135deg, #4facfe 0%, #00f2fe 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">📈 Gower</div>
#                 <div style="font-size: 20px; font-weight: bold;">0.054</div>
#             </div>
#             <div style="background: linear-gradient(135deg, #11998e 0%, #38ef7d 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">📏 NRMSE</div>
#                 <div style="font-size: 20px; font-weight: bold;">0.132</div>
#             </div>
#             <div style="background: linear-gradient(135deg, #ff6b6b 0%, #ee5a24 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">📐 R²</div>
#                 <div style="font-size: 20px; font-weight: bold;">0.506</div>
#             </div>
#         </div>
#         <div class="info-box">
#             ⏱️ Tempo: 1.32 segundos |
#             RMSE: 3.127 | MAE: 2.228 | NMAE: 0.0925 |
#             MAPE: 21.73% | sMAPE: 21.42% | Corr: 0.727 |
#             SMAE_Cont: 0.721 | SMAE_Cat: 0.692 | Erro Corr: 0.0245
#         </div>
# <div class="metrics-highlight">🔷 BOOTSTRAP 13/100 - Proporção missing: 15%</div>
#         <div style="display: grid; grid-template-columns: repeat(5, 1fr); gap: 10px; margin: 10px 0;">
#             <div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">🎯 Acurácia</div>
#                 <div style="font-size: 20px; font-weight: bold;">72.78%</div>
#             </div>
#             <div style="background: linear-gradient(135deg, #f093fb 0%, #f5576c 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">⚖️ F1</div>
#                 <div style="font-size: 20px; font-weight: bold;">51.94%</div>
#             </div>
#             <div style="background: linear-gradient(135deg, #4facfe 0%, #00f2fe 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">📈 Gower</div>
#                 <div style="font-size: 20px; font-weight: bold;">0.048</div>
#             </div>
#             <div style="background: linear-gradient(135deg, #11998e 0%, #38ef7d 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">📏 NRMSE</div>
#                 <div style="font-size: 20px; font-weight: bold;">0.197</div>
#             </div>
#             <div style="background: linear-gradient(135deg, #ff6b6b 0%, #ee5a24 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">📐 R²</div>
#                 <div style="font-size: 20px; font-weight: bold;">0.178</div>
#             </div>
#         </div>
#         <div class="info-box">
#             ⏱️ Tempo: 1.22 segundos |
#             RMSE: 4.047 | MAE: 2.752 | NMAE: 0.1362 |
#             MAPE: 29.49% | sMAPE: 26.43% | Corr: 0.477 |
#             SMAE_Cont: 0.837 | SMAE_Cat: 0.630 | Erro Corr: 0.0401
#         </div>
# <div class="metrics-highlight">🔷 BOOTSTRAP 14/100 - Proporção missing: 15%</div>
#         <div style="display: grid; grid-template-columns: repeat(5, 1fr); gap: 10px; margin: 10px 0;">
#             <div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">🎯 Acurácia</div>
#                 <div style="font-size: 20px; font-weight: bold;">71.11%</div>
#             </div>
#             <div style="background: linear-gradient(135deg, #f093fb 0%, #f5576c 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">⚖️ F1</div>
#                 <div style="font-size: 20px; font-weight: bold;">46.21%</div>
#             </div>
#             <div style="background: linear-gradient(135deg, #4facfe 0%, #00f2fe 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">📈 Gower</div>
#                 <div style="font-size: 20px; font-weight: bold;">0.052</div>
#             </div>
#             <div style="background: linear-gradient(135deg, #11998e 0%, #38ef7d 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">📏 NRMSE</div>
#                 <div style="font-size: 20px; font-weight: bold;">0.187</div>
#             </div>
#             <div style="background: linear-gradient(135deg, #ff6b6b 0%, #ee5a24 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">📐 R²</div>
#                 <div style="font-size: 20px; font-weight: bold;">0.410</div>
#             </div>
#         </div>
#         <div class="info-box">
#             ⏱️ Tempo: 1.33 segundos |
#             RMSE: 3.564 | MAE: 2.545 | NMAE: 0.1347 |
#             MAPE: 27.03% | sMAPE: 23.52% | Corr: 0.642 |
#             SMAE_Cont: 0.708 | SMAE_Cat: 0.554 | Erro Corr: 0.0333
#         </div>
# <div class="metrics-highlight">🔷 BOOTSTRAP 15/100 - Proporção missing: 15%</div>
#         <div style="display: grid; grid-template-columns: repeat(5, 1fr); gap: 10px; margin: 10px 0;">
#             <div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">🎯 Acurácia</div>
#                 <div style="font-size: 20px; font-weight: bold;">63.89%</div>
#             </div>
#             <div style="background: linear-gradient(135deg, #f093fb 0%, #f5576c 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">⚖️ F1</div>
#                 <div style="font-size: 20px; font-weight: bold;">42.03%</div>
#             </div>
#             <div style="background: linear-gradient(135deg, #4facfe 0%, #00f2fe 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">📈 Gower</div>
#                 <div style="font-size: 20px; font-weight: bold;">0.063</div>
#             </div>
#             <div style="background: linear-gradient(135deg, #11998e 0%, #38ef7d 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">📏 NRMSE</div>
#                 <div style="font-size: 20px; font-weight: bold;">0.151</div>
#             </div>
#             <div style="background: linear-gradient(135deg, #ff6b6b 0%, #ee5a24 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">📐 R²</div>
#                 <div style="font-size: 20px; font-weight: bold;">0.463</div>
#             </div>
#         </div>
#         <div class="info-box">
#             ⏱️ Tempo: 2.21 segundos |
#             RMSE: 3.910 | MAE: 2.996 | NMAE: 0.1115 |
#             MAPE: 27.16% | sMAPE: 25.80% | Corr: 0.715 |
#             SMAE_Cont: 0.714 | SMAE_Cat: 0.746 | Erro Corr: 0.0277
#         </div>
# <div class="metrics-highlight">🔷 BOOTSTRAP 16/100 - Proporção missing: 15%</div>
#         <div style="display: grid; grid-template-columns: repeat(5, 1fr); gap: 10px; margin: 10px 0;">
#             <div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">🎯 Acurácia</div>
#                 <div style="font-size: 20px; font-weight: bold;">68.89%</div>
#             </div>
#             <div style="background: linear-gradient(135deg, #f093fb 0%, #f5576c 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">⚖️ F1</div>
#                 <div style="font-size: 20px; font-weight: bold;">48.31%</div>
#             </div>
#             <div style="background: linear-gradient(135deg, #4facfe 0%, #00f2fe 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">📈 Gower</div>
#                 <div style="font-size: 20px; font-weight: bold;">0.054</div>
#             </div>
#             <div style="background: linear-gradient(135deg, #11998e 0%, #38ef7d 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">📏 NRMSE</div>
#                 <div style="font-size: 20px; font-weight: bold;">0.149</div>
#             </div>
#             <div style="background: linear-gradient(135deg, #ff6b6b 0%, #ee5a24 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">📐 R²</div>
#                 <div style="font-size: 20px; font-weight: bold;">0.587</div>
#             </div>
#         </div>
#         <div class="info-box">
#             ⏱️ Tempo: 1.76 segundos |
#             RMSE: 2.962 | MAE: 2.325 | NMAE: 0.1060 |
#             MAPE: 23.85% | sMAPE: 21.82% | Corr: 0.828 |
#             SMAE_Cont: 0.611 | SMAE_Cat: 0.798 | Erro Corr: 0.0125
#         </div>
# <div class="metrics-highlight">🔷 BOOTSTRAP 17/100 - Proporção missing: 15%</div>
#         <div style="display: grid; grid-template-columns: repeat(5, 1fr); gap: 10px; margin: 10px 0;">
#             <div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">🎯 Acurácia</div>
#                 <div style="font-size: 20px; font-weight: bold;">64.44%</div>
#             </div>
#             <div style="background: linear-gradient(135deg, #f093fb 0%, #f5576c 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">⚖️ F1</div>
#                 <div style="font-size: 20px; font-weight: bold;">37.00%</div>
#             </div>
#             <div style="background: linear-gradient(135deg, #4facfe 0%, #00f2fe 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">📈 Gower</div>
#                 <div style="font-size: 20px; font-weight: bold;">0.061</div>
#             </div>
#             <div style="background: linear-gradient(135deg, #11998e 0%, #38ef7d 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">📏 NRMSE</div>
#                 <div style="font-size: 20px; font-weight: bold;">0.163</div>
#             </div>
#             <div style="background: linear-gradient(135deg, #ff6b6b 0%, #ee5a24 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">📐 R²</div>
#                 <div style="font-size: 20px; font-weight: bold;">0.392</div>
#             </div>
#         </div>
#         <div class="info-box">
#             ⏱️ Tempo: 1.55 segundos |
#             RMSE: 3.603 | MAE: 2.689 | NMAE: 0.1237 |
#             MAPE: 32.00% | sMAPE: 27.27% | Corr: 0.645 |
#             SMAE_Cont: 0.735 | SMAE_Cat: 0.791 | Erro Corr: 0.0337
#         </div>
# <div class="metrics-highlight">🔷 BOOTSTRAP 18/100 - Proporção missing: 15%</div>
#         <div style="display: grid; grid-template-columns: repeat(5, 1fr); gap: 10px; margin: 10px 0;">
#             <div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">🎯 Acurácia</div>
#                 <div style="font-size: 20px; font-weight: bold;">66.67%</div>
#             </div>
#             <div style="background: linear-gradient(135deg, #f093fb 0%, #f5576c 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">⚖️ F1</div>
#                 <div style="font-size: 20px; font-weight: bold;">52.20%</div>
#             </div>
#             <div style="background: linear-gradient(135deg, #4facfe 0%, #00f2fe 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">📈 Gower</div>
#                 <div style="font-size: 20px; font-weight: bold;">0.064</div>
#             </div>
#             <div style="background: linear-gradient(135deg, #11998e 0%, #38ef7d 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">📏 NRMSE</div>
#                 <div style="font-size: 20px; font-weight: bold;">0.239</div>
#             </div>
#             <div style="background: linear-gradient(135deg, #ff6b6b 0%, #ee5a24 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">📐 R²</div>
# ...
#                 <div style="font-size: 12px;">🎯 Acurácia</div>
#                 <div style="font-size: 20px; font-weight: bold;">60.00%</div>
#             </div>
#             <div style="background: linear-gradient(135deg, #f093fb 0%, #f5576c 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">⚖️ F1</div>
#                 <div style="font-size: 20px; font-weight: bold;">28.99%</div>
#             </div>
#             <div style="background: linear-gradient(135deg, #4facfe 0%, #00f2fe 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">📈 Gower</div>
#                 <div style="font-size: 20px; font-weight: bold;">0.237</div>
#             </div>
#             <div style="background: linear-gradient(135deg, #11998e 0%, #38ef7d 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">📏 NRMSE</div>
#                 <div style="font-size: 20px; font-weight: bold;">0.149</div>
#             </div>
#             <div style="background: linear-gradient(135deg, #ff6b6b 0%, #ee5a24 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">📐 R²</div>
#                 <div style="font-size: 20px; font-weight: bold;">0.176</div>
#             </div>
#         </div>
#         <div class="info-box">
#             ⏱️ Tempo: 5.48 segundos |
#             RMSE: 4.088 | MAE: 3.254 | NMAE: 0.1152 |
#             MAPE: 33.43% | sMAPE: 28.56% | Corr: 0.473 |
#             SMAE_Cont: 0.938 | SMAE_Cat: 0.953 | Erro Corr: 0.0700
#         </div>
# <div class="metrics-highlight">🔷 BOOTSTRAP 32/100 - Proporção missing: 75%</div>
#         <div style="display: grid; grid-template-columns: repeat(5, 1fr); gap: 10px; margin: 10px 0;">
#             <div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">🎯 Acurácia</div>
#                 <div style="font-size: 20px; font-weight: bold;">58.69%</div>
#             </div>
#             <div style="background: linear-gradient(135deg, #f093fb 0%, #f5576c 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">⚖️ F1</div>
#                 <div style="font-size: 20px; font-weight: bold;">28.25%</div>
#             </div>
#             <div style="background: linear-gradient(135deg, #4facfe 0%, #00f2fe 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">📈 Gower</div>
#                 <div style="font-size: 20px; font-weight: bold;">0.250</div>
#             </div>
#             <div style="background: linear-gradient(135deg, #11998e 0%, #38ef7d 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">📏 NRMSE</div>
#                 <div style="font-size: 20px; font-weight: bold;">0.188</div>
#             </div>
#             <div style="background: linear-gradient(135deg, #ff6b6b 0%, #ee5a24 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">📐 R²</div>
#                 <div style="font-size: 20px; font-weight: bold;">0.046</div>
#             </div>
#         </div>
#         <div class="info-box">
#             ⏱️ Tempo: 4.22 segundos |
#             RMSE: 5.084 | MAE: 3.573 | NMAE: 0.1344 |
#             MAPE: 32.80% | sMAPE: 31.25% | Corr: 0.306 |
#             SMAE_Cont: 0.912 | SMAE_Cat: 0.971 | Erro Corr: 0.1907
#         </div>
# <div class="metrics-highlight">🔷 BOOTSTRAP 33/100 - Proporção missing: 75%</div>
#         <div style="display: grid; grid-template-columns: repeat(5, 1fr); gap: 10px; margin: 10px 0;">
#             <div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">🎯 Acurácia</div>
#                 <div style="font-size: 20px; font-weight: bold;">58.69%</div>
#             </div>
#             <div style="background: linear-gradient(135deg, #f093fb 0%, #f5576c 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">⚖️ F1</div>
#                 <div style="font-size: 20px; font-weight: bold;">30.37%</div>
#             </div>
#             <div style="background: linear-gradient(135deg, #4facfe 0%, #00f2fe 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">📈 Gower</div>
#                 <div style="font-size: 20px; font-weight: bold;">0.247</div>
#             </div>
#             <div style="background: linear-gradient(135deg, #11998e 0%, #38ef7d 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">📏 NRMSE</div>
#                 <div style="font-size: 20px; font-weight: bold;">0.167</div>
#             </div>
#             <div style="background: linear-gradient(135deg, #ff6b6b 0%, #ee5a24 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">📐 R²</div>
#                 <div style="font-size: 20px; font-weight: bold;">0.115</div>
#             </div>
#         </div>
#         <div class="info-box">
#             ⏱️ Tempo: 3.95 segundos |
#             RMSE: 4.576 | MAE: 3.347 | NMAE: 0.1230 |
#             MAPE: 35.46% | sMAPE: 30.84% | Corr: 0.384 |
#             SMAE_Cont: 0.941 | SMAE_Cat: 0.920 | Erro Corr: 0.1099
#         </div>
# <div class="metrics-highlight">🔷 BOOTSTRAP 34/100 - Proporção missing: 75%</div>
#         <div style="display: grid; grid-template-columns: repeat(5, 1fr); gap: 10px; margin: 10px 0;">
#             <div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">🎯 Acurácia</div>
#                 <div style="font-size: 20px; font-weight: bold;">63.61%</div>
#             </div>
#             <div style="background: linear-gradient(135deg, #f093fb 0%, #f5576c 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">⚖️ F1</div>
#                 <div style="font-size: 20px; font-weight: bold;">33.84%</div>
#             </div>
#             <div style="background: linear-gradient(135deg, #4facfe 0%, #00f2fe 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">📈 Gower</div>
#                 <div style="font-size: 20px; font-weight: bold;">0.219</div>
#             </div>
#             <div style="background: linear-gradient(135deg, #11998e 0%, #38ef7d 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">📏 NRMSE</div>
#                 <div style="font-size: 20px; font-weight: bold;">0.157</div>
#             </div>
#             <div style="background: linear-gradient(135deg, #ff6b6b 0%, #ee5a24 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">📐 R²</div>
#                 <div style="font-size: 20px; font-weight: bold;">0.135</div>
#             </div>
#         </div>
#         <div class="info-box">
#             ⏱️ Tempo: 5.28 segundos |
#             RMSE: 4.510 | MAE: 3.330 | NMAE: 0.1108 |
#             MAPE: 34.64% | sMAPE: 30.40% | Corr: 0.427 |
#             SMAE_Cont: 0.908 | SMAE_Cat: 0.910 | Erro Corr: 0.2600
#         </div>
# <div class="metrics-highlight">🔷 BOOTSTRAP 35/100 - Proporção missing: 75%</div>
#         <div style="display: grid; grid-template-columns: repeat(5, 1fr); gap: 10px; margin: 10px 0;">
#             <div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">🎯 Acurácia</div>
#                 <div style="font-size: 20px; font-weight: bold;">60.44%</div>
#             </div>
#             <div style="background: linear-gradient(135deg, #f093fb 0%, #f5576c 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">⚖️ F1</div>
#                 <div style="font-size: 20px; font-weight: bold;">29.85%</div>
#             </div>
#             <div style="background: linear-gradient(135deg, #4facfe 0%, #00f2fe 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">📈 Gower</div>
#                 <div style="font-size: 20px; font-weight: bold;">0.240</div>
#             </div>
#             <div style="background: linear-gradient(135deg, #11998e 0%, #38ef7d 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">📏 NRMSE</div>
#                 <div style="font-size: 20px; font-weight: bold;">0.180</div>
#             </div>
#             <div style="background: linear-gradient(135deg, #ff6b6b 0%, #ee5a24 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">📐 R²</div>
#                 <div style="font-size: 20px; font-weight: bold;">0.085</div>
#             </div>
#         </div>
#         <div class="info-box">
#             ⏱️ Tempo: 5.19 segundos |
#             RMSE: 5.144 | MAE: 3.684 | NMAE: 0.1325 |
#             MAPE: 36.06% | sMAPE: 31.84% | Corr: 0.352 |
#             SMAE_Cont: 0.926 | SMAE_Cat: 0.978 | Erro Corr: 0.0965
#         </div>
# <div class="metrics-highlight">🔷 BOOTSTRAP 36/100 - Proporção missing: 75%</div>
#         <div style="display: grid; grid-template-columns: repeat(5, 1fr); gap: 10px; margin: 10px 0;">
#             <div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">🎯 Acurácia</div>
#                 <div style="font-size: 20px; font-weight: bold;">59.78%</div>
#             </div>
#             <div style="background: linear-gradient(135deg, #f093fb 0%, #f5576c 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">⚖️ F1</div>
#                 <div style="font-size: 20px; font-weight: bold;">30.95%</div>
#             </div>
#             <div style="background: linear-gradient(135deg, #4facfe 0%, #00f2fe 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">📈 Gower</div>
#                 <div style="font-size: 20px; font-weight: bold;">0.243</div>
#             </div>
#             <div style="background: linear-gradient(135deg, #11998e 0%, #38ef7d 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">📏 NRMSE</div>
#                 <div style="font-size: 20px; font-weight: bold;">0.183</div>
#             </div>
#             <div style="background: linear-gradient(135deg, #ff6b6b 0%, #ee5a24 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">📐 R²</div>
#                 <div style="font-size: 20px; font-weight: bold;">0.018</div>
#             </div>
#         </div>
#         <div class="info-box">
#             ⏱️ Tempo: 3.97 segundos |
#             RMSE: 4.787 | MAE: 3.443 | NMAE: 0.1310 |
#             MAPE: 31.39% | sMAPE: 31.60% | Corr: 0.384 |
#             SMAE_Cont: 0.925 | SMAE_Cat: 0.971 | Erro Corr: 0.0280
#         </div>
# <div class="metrics-highlight">🔷 BOOTSTRAP 37/100 - Proporção missing: 75%</div>
#         <div style="display: grid; grid-template-columns: repeat(5, 1fr); gap: 10px; margin: 10px 0;">
#             <div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">🎯 Acurácia</div>
#                 <div style="font-size: 20px; font-weight: bold;">61.64%</div>
#             </div>
#             <div style="background: linear-gradient(135deg, #f093fb 0%, #f5576c 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">⚖️ F1</div>
#                 <div style="font-size: 20px; font-weight: bold;">29.35%</div>
#             </div>
#             <div style="background: linear-gradient(135deg, #4facfe 0%, #00f2fe 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">📈 Gower</div>
#                 <div style="font-size: 20px; font-weight: bold;">0.231</div>
#             </div>
#             <div style="background: linear-gradient(135deg, #11998e 0%, #38ef7d 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">📏 NRMSE</div>
#                 <div style="font-size: 20px; font-weight: bold;">0.170</div>
#             </div>
#             <div style="background: linear-gradient(135deg, #ff6b6b 0%, #ee5a24 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">📐 R²</div>
#                 <div style="font-size: 20px; font-weight: bold;">0.059</div>
#             </div>
#         </div>
#         <div class="info-box">
#             ⏱️ Tempo: 5.27 segundos |
#             RMSE: 5.177 | MAE: 3.657 | NMAE: 0.1194 |
#             MAPE: 31.70% | sMAPE: 30.81% | Corr: 0.387 |
#             SMAE_Cont: 0.930 | SMAE_Cat: 0.974 | Erro Corr: 0.0502
#         </div>
# <div class="metrics-highlight">🔷 BOOTSTRAP 38/100 - Proporção missing: 75%</div>
#         <div style="display: grid; grid-template-columns: repeat(5, 1fr); gap: 10px; margin: 10px 0;">
#             <div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">🎯 Acurácia</div>
#                 <div style="font-size: 20px; font-weight: bold;">59.34%</div>
#             </div>
#             <div style="background: linear-gradient(135deg, #f093fb 0%, #f5576c 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">⚖️ F1</div>
#                 <div style="font-size: 20px; font-weight: bold;">32.72%</div>
#             </div>
#             <div style="background: linear-gradient(135deg, #4facfe 0%, #00f2fe 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">📈 Gower</div>
#                 <div style="font-size: 20px; font-weight: bold;">0.242</div>
#             </div>
#             <div style="background: linear-gradient(135deg, #11998e 0%, #38ef7d 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">📏 NRMSE</div>
#                 <div style="font-size: 20px; font-weight: bold;">0.177</div>
#             </div>
#             <div style="background: linear-gradient(135deg, #ff6b6b 0%, #ee5a24 100%); color: white; padding: 10px; border-radius: 8px; text-align: center;">
#                 <div style="font-size: 12px;">📐 R²</div>
#                 <div style="font-size: 20px; font-weight: bold;">0.066</div>
#             </div>
#         </div>
#         <div class="info-box">
#             ⏱️ Tempo: 3.57 segundos |
#             RMSE: 4.710 | MAE: 3.437 | NMAE: 0.1336 |
#             MAPE: 36.65% | sMAPE: 31.06% | Corr: 0.308 |
#             SMAE_Cont: 0.970 | SMAE_Cat: 1.022 | Erro Corr: 0.1341
#         </div>
# <div class="metrics-highlight">🔷 BOOTSTRAP 39/100 - Proporção missing: 75%</div>
